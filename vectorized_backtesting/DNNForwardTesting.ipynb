# %% [markdown]
# # Deep Neural Network Forward Tester

# %% [markdown]
# Since we split our dataset into training/test sets with an 80/20 split, our test data begins on 2021-12-14 00:00:00. Thus, we will conduct our forward testing on data from 2021-12-14 to 2023-08-01.

# %%
from DeepNeuralNetworkTest import DeepNeuralNetworkTest

# %%
dnn = DeepNeuralNetworkTest('EURUSD=X', start='2021-12-14', end='2023-08-01', tc=0.00007, granularity='1h')

# %%
dnn.load_model(model_path='../deep_neural_network/DNN_Save', pkl_path='../deep_neural_network/parameters.pkl')
dnn.test_strategy()
dnn.results.trades.value_counts()
# Out:
# 312/312 [==============================] - 1s 1ms/step
# Datetime
# 2021-12-22 21:00:00+00:00    0.0
# 2021-12-22 22:00:00+00:00    0.0
# 2021-12-22 23:00:00+00:00    0.0
# 2021-12-23 00:00:00+00:00    0.0
# 2021-12-23 01:00:00+00:00    0.0
#                             ...
# 2023-07-31 19:00:00+01:00    0.0
# 2023-07-31 20:00:00+01:00    0.0
# 2023-07-31 21:00:00+01:00    0.0
# 2023-07-31 22:00:00+01:00    2.0
# 2023-07-31 23:00:00+01:00    0.0
# Name: trades, Length: 9947, dtype: float64

# %%
dnn.plot_results()
